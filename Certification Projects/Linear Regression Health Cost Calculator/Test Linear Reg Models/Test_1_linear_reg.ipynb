# %% [markdown]
# # Notebook Overview
# This Test Uses a single linear neuron

# %%
# !pip install -q git+https://github.com/tensorflow/docs
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
try:
  # %tensorflow_version 2.x
except Exception:
  pass
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense, Sequential
import tensorflow_docs as tfdocs
import tensorflow_docs.plots
import tensorflow_docs.modeling
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# !wget https://cdn.freecodecamp.org/project-data/health-costs/insurance.csv
dataset = pd.read_csv('insurance.csv')

labels = dataset.pop("expenses")
categorical = ["sex","smoker","region"]
dataset = pd.get_dummies(dataset, columns = categorical, drop_first = True)

scaler = StandardScaler()
dataset[["age","bmi","children"]] = scaler.fit_transform(dataset[["age","bmi","children"]])

X = dataset.values
Y = labels.values

train_dataset,test_dataset,train_labels,test_labels = train_test_split(X,Y,test_size = 0.2,random_state = 42)

model = Sequential()
model.add(Input(shape = (train_dataset.shape[1],)))
model.add(Dense(64, activation= 'relu'))
model.add(Dense(64, activation= 'relu'))
model.add(Dense(1, activation= 'linear'))

model.compile(optimizer='adam',loss = 'mse',metrics = ['mae', 'mse'])

model.fit(train_dataset.astype('float32'),train_labels,epochs = 100,batch_size =32)

loss, mae, mse = model.evaluate(test_dataset.astype('float32'), test_labels, verbose=2)

print("Testing set Mean Abs Error: {:5.2f} expenses".format(mae))

if mae < 3500:
  print("You passed the challenge. Great job!")
else:
  print("The Mean Abs Error must be less than 3500. Keep trying.")

test_predictions = model.predict(test_dataset.astype('float32')).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True values (expenses)')
plt.ylabel('Predictions (expenses)')
lims = [0, 50000]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims,lims)

# %% [markdown]
# # Notebook Overview
# This Test Uses a single neuron

# %%
# Import libraries. You may or may not use all of these.
# !pip install -q git+https://github.com/tensorflow/docs
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras.layers import Dense

import tensorflow_docs as tfdocs
import tensorflow_docs.plots
import tensorflow_docs.modeling
# Out:
#   Preparing metadata (setup.py) ... done
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
# Import data
# !wget https://cdn.freecodecamp.org/project-data/health-costs/insurance.csv
dataset = pd.read_csv('insurance.csv')
# Out:
# --2026-05-25 12:42:34--  https://cdn.freecodecamp.org/project-data/health-costs/insurance.csv
# Resolving cdn.freecodecamp.org (cdn.freecodecamp.org)... 104.26.2.33, 172.67.70.149, 104.26.3.33, ...
# Connecting to cdn.freecodecamp.org (cdn.freecodecamp.org)|104.26.2.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 50264 (49K) [text/csv]
# Saving to: ‘insurance.csv’
#
# insurance.csv       100%[===================>]  49.09K  --.-KB/s    in 0.001s
#
# 2026-05-25 12:42:35 (47.0 MB/s) - ‘insurance.csv’ saved [50264/50264]

# %%
dataset.tail()
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36

# %%
# size of dataset
dataset.shape
# Out:
# (1338, 7)

# %%
# investigating for null values

dataset.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
# isolating labels

labels = dataset.pop("expenses")

# %%
# unique regions
dataset['region'].nunique()
# Out:
# 4

# %%
dataset.head()
# Out:
#    age     sex   bmi  children smoker     region
# 0   19  female  27.9         0    yes  southwest
# 1   18    male  33.8         1     no  southeast
# 2   28    male  33.0         3     no  southeast
# 3   33    male  22.7         0     no  northwest
# 4   32    male  28.9         0     no  northwest

# %%
# converting categorical columns to onehot encode

categorical = ["sex","smoker","region"]
# drop first column for statistical significance

dataset = pd.get_dummies(dataset, columns = categorical, drop_first = True,dtype=int)

# %%
dataset.head()
# Out:
#    age   bmi  children  sex_male  smoker_yes  region_northwest  \
# 0   19  27.9         0     False        True             False
# 1   18  33.8         1      True       False             False
# 2   28  33.0         3      True       False             False
# 3   33  22.7         0      True       False              True
# 4   32  28.9         0      True       False              True
#
#    region_southeast  region_southwest
# 0             False              True
# 1              True             False
# 2              True             False
# 3             False             False
# 4             False             False

# %%
# normalizing data

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
dataset[["age","bmi","children"]] = scaler.fit_transform(dataset[["age","bmi","children"]])

# %%
dataset[['age','bmi','children']] # standardized
# Out:
#            age       bmi  children
# 0    -1.438764 -0.453646 -0.908614
# 1    -1.509965  0.514186 -0.078767
# 2    -0.797954  0.382954  1.580926
# 3    -0.441948 -1.306650 -0.908614
# 4    -0.513149 -0.289606 -0.908614
# ...        ...       ...       ...
# 1333  0.768473  0.054876  1.580926
# 1334 -1.509965  0.202511 -0.908614
# 1335 -1.509965  1.022707 -0.908614
# 1336 -1.296362 -0.798128 -0.908614
# 1337  1.551686 -0.256799 -0.908614
#
# [1338 rows x 3 columns]

# %%
X = dataset.values
Y = labels.values

# %%
# split and shuffle
from sklearn.model_selection import train_test_split

train_dataset,test_dataset,train_labels,test_labels = train_test_split(X,Y,test_size = 0.2,random_state = 42)

# %%
test_labels.shape
# Out:
# (268,)

# %%
train_dataset.shape
# Out:
# (1070, 8)

# %%
# model creation

from keras import Sequential
from keras.layers import Input
from keras.layers import Dense

model = Sequential()
model.add(Input(shape = (train_dataset.shape[1],)))
model.add(Dense(1, activation= 'linear'))

# %%
# compile model

model.compile(optimizer='adam',loss = 'mse',metrics = ['mae', 'mse'])

# %%
'''
fitting model
converting the categorical columns to floats as they are currently bools
'''
model.fit(train_dataset,train_labels,epochs = 100,batch_size =32)
# Out:
# Epoch 1/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 322453472.0000 - mae: 13346.2148 - mse: 322453472.0000
# Epoch 2/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 322450784.0000 - mae: 13346.1387 - mse: 322450784.0000
# Epoch 3/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 322448096.0000 - mae: 13346.0547 - mse: 322448096.0000
# Epoch 4/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 322445376.0000 - mae: 13345.9766 - mse: 322445376.0000
# Epoch 5/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 322442816.0000 - mae: 13345.8945 - mse: 322442816.0000
# Epoch 6/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 322440096.0000 - mae: 13345.8174 - mse: 322440096.0000
# Epoch 7/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 322437440.0000 - mae: 13345.7354 - mse: 322437440.0000
# Epoch 8/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 322434688.0000 - mae: 13345.6572 - mse: 322434688.0000
# Epoch 9/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 322432032.0000 - mae: 13345.5771 - mse: 322432032.0000
# Epoch 10/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 322429376.0000 - mae: 13345.4941 - mse: 322429376.0000
# Epoch 11/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 322426624.0000 - mae: 13345.4131 - mse: 322426624.0000
# Epoch 12/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322423936.0000 - mae: 13345.3379 - mse: 322423936.0000
# Epoch 13/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322421280.0000 - mae: 13345.2559 - mse: 322421280.0000
# Epoch 14/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322418528.0000 - mae: 13345.1748 - mse: 322418528.0000
# Epoch 15/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322415904.0000 - mae: 13345.0928 - mse: 322415904.0000
# Epoch 16/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322413248.0000 - mae: 13345.0137 - mse: 322413248.0000
# Epoch 17/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322410496.0000 - mae: 13344.9346 - mse: 322410496.0000
# Epoch 18/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322407872.0000 - mae: 13344.8535 - mse: 322407872.0000
# Epoch 19/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322405088.0000 - mae: 13344.7715 - mse: 322405088.0000
# Epoch 20/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322402432.0000 - mae: 13344.6895 - mse: 322402432.0000
# Epoch 21/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322399776.0000 - mae: 13344.6123 - mse: 322399776.0000
# Epoch 22/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322397088.0000 - mae: 13344.5322 - mse: 322397088.0000
# Epoch 23/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322394400.0000 - mae: 13344.4512 - mse: 322394400.0000
# Epoch 24/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 
# Epoch 70/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322268448.0000 - mae: 13340.6807 - mse: 322268448.0000
# Epoch 71/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322265792.0000 - mae: 13340.6025 - mse: 322265792.0000
# Epoch 72/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322263072.0000 - mae: 13340.5225 - mse: 322263072.0000
# Epoch 73/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322260480.0000 - mae: 13340.4404 - mse: 322260480.0000
# Epoch 74/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322257760.0000 - mae: 13340.3623 - mse: 322257760.0000
# Epoch 75/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322255104.0000 - mae: 13340.2812 - mse: 322255104.0000
# Epoch 76/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322252416.0000 - mae: 13340.2021 - mse: 322252416.0000
# Epoch 77/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322249728.0000 - mae: 13340.1201 - mse: 322249728.0000
# Epoch 78/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322247040.0000 - mae: 13340.0400 - mse: 322247040.0000
# Epoch 79/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322244384.0000 - mae: 13339.9609 - mse: 322244384.0000
# Epoch 80/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322241664.0000 - mae: 13339.8789 - mse: 322241664.0000
# Epoch 81/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322239008.0000 - mae: 13339.7969 - mse: 322239008.0000
# Epoch 82/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322236320.0000 - mae: 13339.7178 - mse: 322236320.0000
# Epoch 83/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322233600.0000 - mae: 13339.6416 - mse: 322233600.0000
# Epoch 84/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322230944.0000 - mae: 13339.5576 - mse: 322230944.0000
# Epoch 85/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322228256.0000 - mae: 13339.4756 - mse: 322228256.0000
# Epoch 86/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322225536.0000 - mae: 13339.3984 - mse: 322225536.0000
# Epoch 87/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322222912.0000 - mae: 13339.3154 - mse: 322222912.0000
# Epoch 88/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322220224.0000 - mae: 13339.2383 - mse: 322220224.0000
# Epoch 89/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322217472.0000 - mae: 13339.1562 - mse: 322217472.0000
# Epoch 90/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322214880.0000 - mae: 13339.0762 - mse: 322214880.0000
# Epoch 91/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 322212128.0000 - mae: 13338.9951 - mse: 322212128.0000
# Epoch 92/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 322209472.0000 - mae: 13338.9170 - mse: 322209472.0000
# Epoch 93/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 322206720.0000 - mae: 13338.8369 - mse: 322206720.0000
# Epoch 94/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 322204128.0000 - mae: 13338.7559 - mse: 322204128.0000
# Epoch 95/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 322201440.0000 - mae: 13338.6758 - mse: 322201440.0000
# Epoch 96/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 322198784.0000 - mae: 13338.5947 - mse: 322198784.0000
# Epoch 97/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 322196000.0000 - mae: 13338.5137 - mse: 322196000.0000
# Epoch 98/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 322193280.0000 - mae: 13338.4316 - mse: 322193280.0000
# Epoch 99/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 322190592.0000 - mae: 13338.3506 - mse: 322190592.0000
# Epoch 100/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322187936.0000 - mae: 13338.2754 - mse: 322187936.0000

# %%
# RUN THIS CELL TO TEST YOUR MODEL. DO NOT MODIFY CONTENTS.
# Test model by checking how well the model generalizes using the test set.
loss, mae, mse = model.evaluate(test_dataset.astype('float32'), test_labels, verbose=2)

print("Testing set Mean Abs Error: {:5.2f} expenses".format(mae))

if mae < 3500:
  print("You passed the challenge. Great job!")
else:
  print("The Mean Abs Error must be less than 3500. Keep trying.")

# Plot predictions.
test_predictions = model.predict(test_dataset.flatten())

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True values (expenses)')
plt.ylabel('Predictions (expenses)')
lims = [0, 50000]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims,lims)
# Out:
# 9/9 - 0s - 7ms/step - loss: 323159360.0000 - mae: 12960.4395 - mse: 323159360.0000
# Testing set Mean Abs Error: 12960.44 expenses
# The Mean Abs Error must be less than 3500. Keep trying.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

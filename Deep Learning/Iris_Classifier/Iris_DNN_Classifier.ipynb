# %%
'''
This cell sets up the Google Colab environment.
This allows other uses to use and test my code on their own devises
It defines the GitHub repository structure where the pre-trained model is stored.
The line urllib.request.urlretrieve(raw_model_url, MODEL_FILENAME) is responsible for downloading the model file from the internet.
It then constructs the raw GitHub URL for the model.
Finally, it defines and executes a function to download the 'dnn_classifier.keras' file
into the Colab environment, ensuring the model is available for use.
'''

import os
import urllib.request #Python module that provides functions and classes to open URLs (mostly HTTP) in a complex world
from tensorflow.keras.models import load_model

# 1. Configuration based  repository structure
GITHUB_USERNAME = "keden49"
REPO_NAME = "Machine-learning-with-python-freecode-camp"
SUB_FOLDER = "Iris-classifier-keras"
MODEL_FILENAME = "dnn_classifier.keras"

# Construct the Raw Github URL Location of model online
raw_model_url = f"https://raw.githubusercontent.com/{GITHUB_USERNAME}/{REPO_NAME}/main/{SUB_FOLDER}/{MODEL_FILENAME}"

def setup_colab_env():
    """Downloads the pre-trained model into the Colab environment."""
    if not os.path.exists(MODEL_FILENAME):
        print(f" Fetching {MODEL_FILENAME} from {SUB_FOLDER}...")
        try:
            urllib.request.urlretrieve(raw_model_url, MODEL_FILENAME)
            print(" Model successfully added to environment.")
        except Exception as e:
            print(f" Download failed. Check if {MODEL_FILENAME} is pushed to the {SUB_FOLDER} folder.")
            print(f"Error details: {e}")
    else:
        print(f" {MODEL_FILENAME} is ready.")

# Execute the setup
setup_colab_env()
# Out:
#  Fetching dnn_classifier.keras from Iris-classifier-keras...
#  Download failed. Check if dnn_classifier.keras is pushed to the Iris-classifier-keras folder.
# Error details: HTTP Error 404: Not Found

# %%
from __future__ import absolute_import, division, print_function, unicode_literals # Import future features for Python 2/3 compatibility
import tensorflow as tf # Import TensorFlow for machine learning
import pandas as pd # Import pandas for data manipulation and analysis

# %%
CSV_COLUMN_NAMES= ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species']
SPECIES= ['Setosa', 'Versicolor', 'Virginica']

# %%
'''
 uses TensorFlow's utility function to download dataset files:
 The lines download the Iris training and testing dataset (a CSV file) from the specified Google Cloud Storage URL.
 The downloaded files will be saved locally as iris_training.csv and iris_testing.csv respectively, and its local path is stored in a variable.
'''

train_path = tf.keras.utils.get_file("iris_training.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_training.csv")
test_path = tf.keras.utils.get_file("iris_test.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv")
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/iris_training.csv
# 2194/2194 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 0s 2us/step

# %%
''''
Loading dataframes using pandas
pd.read_csv() is used to read the CSV files into pandas dataframes.
paths show the direction of files
names is for column names
header=0 takes row 0 as header
'''
train_df = pd.read_csv(train_path,names=CSV_COLUMN_NAMES,header=0)
test_df =pd.read_csv(test_path,names=CSV_COLUMN_NAMES,header=0)

# %%
#visualizing first few columns of training ds
train_df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth  Species
# 0          6.4         2.8          5.6         2.2        2
# 1          5.0         2.3          3.3         1.0        1
# 2          4.9         2.5          4.5         1.7        2
# 3          4.9         3.1          1.5         0.1        0
# 4          5.7         3.8          1.7         0.3        0

# %%
#visualizing first few columns of testing ds
test_df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth  Species
# 0          5.9         3.0          4.2         1.5        1
# 1          6.9         3.1          5.4         2.1        2
# 2          5.1         3.3          1.7         0.5        0
# 3          6.0         3.4          4.5         1.6        1
# 4          5.5         2.5          4.0         1.3        1

# %%
#target labels
y_train =train_df.pop('Species')
y_test =test_df.pop('Species')

# %%
'''
shape
120 rows
4 columns
'''

train_df.shape
# Out:
# (120, 4)

# %%
'''
shape
30 rows
4 columns
'''

test_df.shape
# Out:
# (30, 4)

# %%
'''
input shape of data
what changes is the number of rows
but what remains constant is the number of columns
'''
num_features = train_df.shape[1]

# %%
'''
Building DNN Model
relu is the activation fn applied to the output of each neuron
outputs the input directly if it's positive, otherwise, it outputs zero.
ReLU allows the network to learn complex, non-linear patterns.
10 neurons in the 1st hidden layer learn more abstract patterns passed from the input layer
softmax is used for multi-class classification
Each of these 3 neurons will correspond to one of the target classes.
Softmax takes the raw output scores (logits) from the 3 neurons and squashes them into a probability distribution
sum will add up to 1
'''
dnn_classifier = tf.keras.Sequential([
    tf.keras.layers.Dense(30,activation = 'relu',input_shape=(num_features,)), #input layer
    tf.keras.layers.Dense(10,activation = 'relu'), #hidden Layer 1
    tf.keras.layers.Dense(3, activation='softmax') # Output layer with 3 units for 3 species and softmax activation
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
'''
configuring the model
optimizer is the algorithm that adjustes the classifiers internal parameters(weights and biases)
loss quantifies how far off the model's predictions are from the actual target values.
sparse categorical crossentropy is used when the target labels are intergers instead of hot encoded
Metrics are used to estimate model's perfomance
'''

dnn_classifier.compile(optimizer = 'adam',
                       loss = 'sparse_categorical_crossentropy',
                       metrics = ['accuracy'])

# %%
'''
importing Early stopping to prevent overfitting
stops training when no improvement is seen in validation loss
patience tracks the no of epochs to tolerate before stopping
'''
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10,restore_best_weights=True,min_delta=0.00001)

# %%
training_classifier = dnn_classifier.fit(train_df,y_train,
                                         epochs=100,
                                         batch_size=10,#15 weight updates per epoch
                                         validation_data=(test_df,y_test),#Separate data the model hasn't seen during training
                                         callbacks=[early_stop],verbose=1)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7493 - loss: 0.9625 - val_accuracy: 0.5333 - val_loss: 0.9504
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7057 - loss: 0.8928 - val_accuracy: 0.5333 - val_loss: 0.9367
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6426 - loss: 0.8834 - val_accuracy: 0.5333 - val_loss: 0.8986
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6600 - loss: 0.8365 - val_accuracy: 0.5333 - val_loss: 0.8670
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7330 - loss: 0.7658 - val_accuracy: 0.5333 - val_loss: 0.8417
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6903 - loss: 0.7383 - val_accuracy: 0.5333 - val_loss: 0.7854
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7052 - loss: 0.6878 - val_accuracy: 0.5333 - val_loss: 0.7590
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6865 - loss: 0.6834 - val_accuracy: 0.5333 - val_loss: 0.7241
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7150 - loss: 0.6445 - val_accuracy: 0.5333 - val_loss: 0.7070
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7341 - loss: 0.5885 - val_accuracy: 0.5333 - val_loss: 0.6757
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7160 - loss: 0.5697 - val_accuracy: 0.5333 - val_loss: 0.6527
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7015 - loss: 0.5417 - val_accuracy: 0.5333 - val_loss: 0.6423
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7145 - loss: 0.5187 - val_accuracy: 0.5333 - val_loss: 0.6175
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6689 - loss: 0.5424 - val_accuracy: 0.5667 - val_loss: 0.5915
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7480 - loss: 0.4638 - val_accuracy: 0.7333 - val_loss: 0.5474
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8478 - loss: 0.4547 - val_accuracy: 0.7333 - val_loss: 0.5275
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8112 - loss: 0.4504 - val_accuracy: 0.7333 - val_loss: 0.5096
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8064 - loss: 0.4357 - val_accuracy: 0.8333 - val_loss: 0.4846
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8068 - loss: 0.4436 - val_accuracy: 0.6333 - val_loss: 0.5028
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8187 - loss: 0.4148 - val_accuracy: 0.9667 - val_loss: 0.4405
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9172 - loss: 0.3774 - val_accuracy: 0.7667 - val_loss: 0.4652
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8322 - loss: 0.3887 - val_accuracy: 0.9333 - val_loss: 0.4208
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9099 - loss: 0.3723 - val_accuracy: 0.9333 - val_loss: 0.4077
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9044 - loss: 0.3798 - val_accuracy: 0.9333 - val_loss: 0.4007
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9243 - loss: 0.3656 - val_accuracy: 0.9333 - val_loss: 0.3831
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9015 - loss: 0.3406 - val_accuracy: 0.9000 - val_loss: 0.3816
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9187 - loss: 0.2858 - val_accuracy: 0.9667 - val_loss: 0.3512
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9425 - loss: 0.3200 - val_accuracy: 0.9667 - val_loss: 0.3437
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9495 - loss: 0.2879 - val_accuracy: 0.9000 - val_loss: 0.3621
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9697 - loss: 0.2812 - val_accuracy: 0.9667 - val_loss: 0.3107
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9770 - loss: 0.2763 - val_accuracy: 0.9333 - val_loss: 0.3350
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9201 - loss: 0.2781 - val_accuracy: 0.9667 - val_loss: 0.3009
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9643 - loss: 0.2666 - val_accuracy: 0.9667 - val_loss: 0.2955
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9633 - loss: 0.2398 - val_accuracy: 0.9667 - val_loss: 0.2880
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9700 - loss: 0.2264 - val_accuracy: 0.9667 - val_loss: 0.2694
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9807 - loss: 0.2346 - val_accuracy: 0.9667 - val_loss: 0.2712
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9678 - loss: 0.2290 - val_accuracy: 0.9667 - val_loss: 0.2730
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9783 - loss: 0.2196 - val_accuracy: 0.9667 - val_loss: 0.2401
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9915 - loss: 0.2189 - val_accuracy: 0.9667 - val_loss: 0.2511
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9624 - loss: 0.2019 - val_accuracy: 0.9667 - val_loss: 0.2391
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9841 - loss: 0.2078 - val_accuracy: 0.9667 - val_loss: 0.2275
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9849 - loss: 0.1760 - val_accuracy: 0.9667 - val_loss: 0.2200
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9670 - loss: 0.2025 - val_accuracy: 0.9667 - val_loss: 0.2114
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9846 - loss: 0.1788 - val_accuracy: 0.9667 - val_loss: 0.2054
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9681 - loss: 0.1979 - val_accuracy: 0.9667 - val_loss: 0.2009
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9761 - loss: 0.1671 - val_accuracy: 0.9667 - val_loss: 0.1943
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9618 - loss: 0.1755 - val_accuracy: 0.9667 - val_loss: 0.1933
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9698 - loss: 0.1899 - val_accuracy: 0.9667 - val_loss: 0.1764
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9755 - loss: 0.2030 - val_accuracy: 0.9667 - val_loss: 0.1908
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9598 - loss: 0.1724 - val_accuracy: 0.9667 - val_loss: 0.1814
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9715 - loss: 0.1530 - val_accuracy: 0.9667 - val_loss: 0.1748
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9626 - loss: 0.1538 - val_accuracy: 0.9667 - val_loss: 0.1642
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9495 - loss: 0.1682 - val_accuracy: 0.9667 - val_loss: 0.1581
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9581 - loss: 0.1579 - val_accuracy: 0.9667 - val_loss: 0.1815
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9731 - loss: 0.1391 - val_accuracy: 0.9333 - val_loss: 0.1453
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9916 - loss: 0.1485 - val_accuracy: 0.9667 - val_loss: 0.1616
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9781 - loss: 0.1388 - val_accuracy: 0.9667 - val_loss: 0.1449
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9792 - loss: 0.1331 - val_accuracy: 0.9667 - val_loss: 0.1389
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9707 - loss: 0.1500 - val_accuracy: 0.9667 - val_loss: 0.1427
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9773 - loss: 0.1322 - val_accuracy: 0.9667 - val_loss: 0.1344
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9817 - loss: 0.1221 - val_accuracy: 0.9667 - val_loss: 0.1335
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9857 - loss: 0.1212 - val_accuracy: 0.9667 - val_loss: 0.1345
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.1080 - val_accuracy: 0.9667 - val_loss: 0.1329
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9765 - loss: 0.1155 - val_accuracy: 0.9667 - val_loss: 0.1269
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9559 - loss: 0.1358 - val_accuracy: 0.9667 - val_loss: 0.1244
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9485 - loss: 0.1403 - val_accuracy: 0.9667 - val_loss: 0.1388
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9658 - loss: 0.1413 - val_accuracy: 0.9667 - val_loss: 0.1150
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9915 - loss: 0.1108 - val_accuracy: 0.9667 - val_loss: 0.1168
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9874 - loss: 0.1111 - val_accuracy: 0.9667 - val_loss: 0.1228
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9869 - loss: 0.1086 - val_accuracy: 0.9667 - val_loss: 0.1104
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9911 - loss: 0.1229 - val_accuracy: 0.9667 - val_loss: 0.1149
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9651 - loss: 0.1409 - val_accuracy: 0.9667 - val_loss: 0.1085
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9918 - loss: 0.1085 - val_accuracy: 0.9667 - val_loss: 0.1230
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9551 - loss: 0.1402 - val_accuracy: 0.9667 - val_loss: 0.1092
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9890 - loss: 0.1016 - val_accuracy: 0.9667 - val_loss: 0.1138
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9964 - loss: 0.0971 - val_accuracy: 0.9667 - val_loss: 0.1008
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9944 - loss: 0.0973 - val_accuracy: 0.9667 - val_loss: 0.1114
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9879 - loss: 0.0863 - val_accuracy: 0.9667 - val_loss: 0.1000
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9692 - loss: 0.1179 - val_accuracy: 0.9667 - val_loss: 0.1072
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9894 - loss: 0.0826 - val_accuracy: 0.9667 - val_loss: 0.0972
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9741 - loss: 0.1103 - val_accuracy: 0.9667 - val_loss: 0.1043
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9856 - loss: 0.0832 - val_accuracy: 0.9667 - val_loss: 0.1035
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9649 - loss: 0.0931 - val_accuracy: 0.9667 - val_loss: 0.0921
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9916 - loss: 0.0850 - val_accuracy: 0.9667 - val_loss: 0.1051
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9905 - loss: 0.0678 - val_accuracy: 0.9667 - val_loss: 0.0985
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9709 - loss: 0.0983 - val_accuracy: 0.9667 - val_loss: 0.0909
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9843 - loss: 0.0918 - val_accuracy: 0.9667 - val_loss: 0.0930
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9960 - loss: 0.0796 - val_accuracy: 0.9667 - val_loss: 0.0950
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9953 - loss: 0.0835 - val_accuracy: 0.9667 - val_loss: 0.0907
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9775 - loss: 0.0904 - val_accuracy: 0.9667 - val_loss: 0.0880
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9868 - loss: 0.0986 - val_accuracy: 0.9667 - val_loss: 0.0913
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9907 - loss: 0.0816 - val_accuracy: 0.9667 - val_loss: 0.0872
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9804 - loss: 0.1125 - val_accuracy: 0.9667 - val_loss: 0.0923
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9889 - loss: 0.0721 - val_accuracy: 0.9667 - val_loss: 0.0857
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9953 - loss: 0.0671 - val_accuracy: 0.9667 - val_loss: 0.0849
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9927 - loss: 0.0975 - val_accuracy: 0.9667 - val_loss: 0.0869
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9861 - loss: 0.0923 - val_accuracy: 0.9667 - val_loss: 0.0866
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9660 - loss: 0.0888 - val_accuracy: 0.9667 - val_loss: 0.0811
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9918 - loss: 0.0827 - val_accuracy: 0.9667 - val_loss: 0.0966
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9843 - loss: 0.0689 - val_accuracy: 0.9667 - val_loss: 0.0814
# Restoring model weights from the end of the best epoch: 98.

# %%
dnn_classifier.save('dnn_classifier.keras') #saves models last epoch (best weights)

# %%
#using model and loading model
from tensorflow.keras.models import load_model
import numpy as np
loaded_model = load_model('dnn_classifier.keras')

# %%
'''
creating user interface
GOAL : should collect data from user
'''
features = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth']
flowers_info = []

print("Please enter as prompted\n")

for feature in features:
  # Loop until a valid numeric input is received for the current feature
  while True:
    val_str = input(feature + ": ") # Get input directly from user
    if not val_str.isdigit(): # Check if it's a valid number (integer or float)
      print("Invalid input. Please enter a numerical value.")
    # only if user input is valid is it converted to a floaat & appended
    else:
      val = float(val_str)
      flowers_info.append(val)
      break # Break out of the inner loop for this feature if valid
# Out:
# Please enter as prompted
#
# SepalLength: 7
# SepalWidth: 2
# PetalLength: 1
# PetalWidth: 1

# %%
#unpacking users info
print(flowers_info)
# Out:
# [7.0, 2.0, 1.0, 1.0]

# %%
'''
testing models predictions with users info
the model needs the data in a 2D array(row,column)
also needs to be converted to a numpy array
np.argmax returns the indices of the maximum values along an axis.
predictions[0] because it returns a list inside a list hence being the only item it takes index 0
to access the most probable specie i use class_ids
which is returned by np.argmax (index of highest value)
using that i can now get the probability which will in turn give me the specie
ouput is formated to 2 dp
'''
import numpy as np
user_input_array = np.array(flowers_info).reshape(1,-1)
predictions = loaded_model.predict(user_input_array)

#print(predictions)

class_ids= np.argmax(predictions[0])
probabilities = predictions[0][class_ids]
#print(probabilities)
print(f'The flower Specie is {SPECIES[class_ids]} with a probability of ({100 * probabilities:.2f}%)')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# The flower Specie is Setosa with a probability of (97.80%)

# %%
import matplotlib.pyplot as plt

# Create a figure with two subplots: Accuracy and Loss
plt.figure(figsize=(12, 5))

# Plot Accuracy
plt.subplot(1, 2, 1)
plt.plot(training_classifier.history['accuracy'], label='Train Accuracy', color='#4CAF50')
plt.plot(training_classifier.history['val_accuracy'], label='Test Accuracy', color='#FF9800')
plt.title('Model Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(training_classifier.history['loss'], label='Train Loss', color='#F44336')
plt.plot(training_classifier.history['val_loss'], label='Test Loss', color='#2196F3')
plt.title('Model Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# We combine the features and labels for plotting
plot_df = train_df.copy()
plot_df['Species'] = y_train.map({0: 'Setosa', 1: 'Versicolor', 2: 'Virginica'})

# A pairplot shows relationships between every feature
sns.pairplot(plot_df, hue='Species', palette='viridis', markers=["o", "s", "D"])
plt.suptitle("Iris Feature Relationships", y=1.02)
plt.show()
